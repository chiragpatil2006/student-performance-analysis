# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   NaN   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   NaN   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   NaN   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   NaN   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   NaN   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
print("Dataset Shape:", data.shape)
print("\nColumns:", data.columns)
print("\nMissing Values:\n", data.isnull().sum())
# Out:
# Dataset Shape: (178, 10)
#
# Columns: Index(['1st', '2nd', '3rd', '4th', '5th', 'College Code', 'Gender', 'Roll',
#        'Roll no.', 'Subject Code'],
#       dtype='object')
#
# Missing Values:
#  1st               2
# 2nd               4
# 3rd               2
# 4th               5
# 5th               6
# College Code      0
# Gender            1
# Roll             46
# Roll no.        132
# Subject Code      0
# dtype: int64

# %%
data.describe()
# Out:
#               1st         2nd        3rd         4th         5th  \
# count  176.000000  174.000000  176.00000  173.000000  172.000000
# mean     7.038864    6.943391    6.62250    7.027746    7.432558
# std      0.859521    0.881088    0.91926    1.035675    1.068866
# min      3.850000    3.900000    3.96000    4.290000    4.000000
# 25%      6.440000    6.380000    6.14000    6.330000    6.750000
# 50%      7.070000    6.800000    6.68500    7.070000    7.590000
# 75%      7.590000    7.612500    7.26000    7.860000    8.210000
# max      9.150000    9.210000    9.59000    9.310000    9.460000
#
#        College Code          Roll      Roll no.  Subject Code
# count    178.000000    132.000000     46.000000    178.000000
# mean     152.983146  17040.666667  17042.500000     18.359551
# std       48.357599     13.622874     13.422618      4.782849
# min      115.000000  17017.000000  17020.000000     16.000000
# 25%      115.000000  17029.000000  17031.250000     16.000000
# ...

# %%
data = data.fillna(0)
data.head()
# Out:
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   0.0   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   0.0   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   0.0   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   0.0   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   0.0   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Gender", y="1st", data=data, estimator=np.mean)
plt.title("Average Semester 1 Marks by Gender")
plt.show()

# %%
sem_cols = ["1st","2nd","3rd","4th","5th"]
avg_scores = data[sem_cols].mean()
avg_scores.plot(kind="line", marker="o", figsize=(6,4))
plt.title("Average Marks Across Semesters")
plt.xlabel("Semesters")
plt.ylabel("Average Marks")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data[sem_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Semesters")
plt.show()

# %%
top5 = data.sort_values("5th", ascending=False).head(5)
print("Top 5 Students (5th 5):\n", top5[["Roll no.","5th"]])
# Out:
# Top 5 Students (5th 5):
#       Roll no.   5th
# 135       0.0  9.46
# 55        0.0  9.39
# 149       0.0  9.35
# 115       0.0  9.19
# 50        0.0  9.14

# %%
print("Analysis Completed: We explored dataset, cleaned missing values, visualized trends, and identified top students.")
# Out:
# Analysis Completed: We explored dataset, cleaned missing values, visualized trends, and identified top students.
